# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

path = "/home/labs/hornsteinlab/giliwo/NOVA_rotation/embeddings/embedding_and_paths/RotationDatasetConfig/pairs/cosine_dist.png"
img = mpimg.imread(path)
plt.imshow(img)
plt.axis('off')  # Optional: hide axes
plt.show()
